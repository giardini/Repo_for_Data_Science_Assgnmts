# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Angelo Giardini__<br>
# Future Data Scientist

# %% [markdown]
# *I am interested in data science because it helps me to tackle real life problems in a structured, data-driven way, and to communicate solutions by "telling a story".*

# %% [markdown]
# ### The Python code below is supposed to print a simple message.

# %%
print("Hello, my fellow students of data science")
# Out:
# Hello, my fellow students of data science

# %% [markdown]
# |     | Column 1 | Column 2 |
# |-----|----------|----------|
# |Row 1|          |          |
# |Row 2|          |          |
#
#
# - Point 1
# - Point 2
# - Point 3
#
# __[Link to Coursera homepage](http://coursera.org)__
